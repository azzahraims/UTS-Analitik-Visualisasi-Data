# %% [markdown]
# # **Analisis Faktor yang Mempengaruhi Rating dan Popularitas Film Berdasarkan Dataset IMDb Top 1000**

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
# IMDb Movies Dataset
#
# Data ini merupakan sebuah data yang berisi 1000 film dan acara TV terbaik berdasarkan rating IMDb, yang mencakup informasi seperti judul, genre, tahun rilis, durasi, rating, jumlah voting dari penonton, serta tokoh atau pemain film. Data ini mempresentasikan karya hiburan dengan tingkat popularitas dan kualitas yang tinggi menurut penilaian publik.
#
# Permasalahan yang muncul adalah belum optimalnya pemanfaatan data dalam menganalisis pola kesukaan penonton, seperti genre yang paling disukai, durasi film yang cenderung mendapatkan rating tinggi, peran pemain film terhadap performa rating, serta karakteristik film yang memiliki tingkat popularitas besar. Banyak keputusan produksi masih didasarkan pada tren umum tanpa analisis data yang mendalam.
#
# Analisis ini bertujuan agar industri perfilman dapat memperoleh gambaran yang jelas mengenai preferensi penonton sehingga dapat digunakan sebagai bahan pertimbangan dalam membuat film, menentukan konsep cerita, memilih pemain yang sesuai, serta menyusun strategi produksi yang lebih tepat dan berbasis data.

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# Dunia perfilman terus berkembang dengan semakin banyaknya film dan acara TV yang diproduksi setiap tahun, sehingga persaingan kualitas hiburan semakin tinggi. Di tengah banyaknya pilihan tontonan, perusahaan film perlu memahami jenis film yang paling disukai penonton agar dapat menghasilkan karya yang sesuai dengan kebutuhan pasar.
#
# Dataset IMDb Top 1000 menyediakan data penilaian penonton terhadap film dan serial terbaik melalui rating dan jumlah voting, serta dilengkapi dengan informasi genre, durasi, tahun rilis dan tokoh atau pemain film. Namun, data tersebut masih belum dimanfaatkan secara maksimal untuk menggali pola preferensi penonton secara mendalam.
#
# Melalui analasis data ini, industri perfilman memiliki peluang untuk memperoleh wawasan mengenai karakteristik film yang diminati pasar, sehingga dapat mendukung pengambilan keputusan produksi dan strategi bisnis yang lebih tepat.

# %% [markdown]
# ## **Analytic Goal & Project Plan**

# %% [markdown]
# Untuk mencapai tujuan analisis, dilakukan beberapa tahapan pengolahan dan analisis data sebagai berikut:
#
# - Pengumpulan, pembersihan, dan eksplorasi data film berdasarkan dataset yang tersedia.
# - Mengidentifikasi pola hubungan antara genre film, durasi tayang, tahun rilis, dan rating IMDb untuk memahami faktor yang memengaruhi kualitas film.
# - Menganalisis preferensi penonton berdasarkan jumlah voting serta karakteristik film yang diminati pasar.
# - Menganalisis peran tokoh atau pemain film terhadap performa rating, seperti aktor yang sering muncul dalam film dengan rating tinggi.
# - Menyusun visualisasi data dan insight berbasis data untuk membantu industri perfilman dalam perencanaan produksi dan strategi konten.

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %% [markdown]
# Sumber dataset ini berasal dari IMDb Top 1000 Movies, yang bertujuan untuk menganalisis dan mengevaluasi preferensi penonton serta tren film dalam skala global.

# %%
file = '/content/drive/MyDrive/AVD/imdb_top_1000.csv'
df = pd.read_csv(file)

df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 1000 Baris dan 16 Kolom

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# **1. Poster_Link**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Link atau URL poster film.
#
# **2. Series_Title**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Judul film atau serial.
#
# **3. Released_Year**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Tahun rilis film atau serial.
#
# **4. Certificate**
#
# Jumlah baris: 899
# Tipe data: object
# Deskripsi: Klasifikasi usia atau rating penonton (misalnya PG-13, R, dll).
#
# **5. Runtime**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Durasi film dalam satuan menit.
#
# **6. Genre**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Genre atau kategori film (misalnya Drama, Action, Comedy, dll).
#
# **7. IMDB_Rating**
#
# Jumlah baris: 1000
# Tipe data: float64
# Deskripsi: Nilai rating film berdasarkan penilaian pengguna IMDb.
#
# **8. Overview**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Ringkasan atau sinopsis singkat cerita film.
#
# **9. Meta_score**
#
# Jumlah baris: 843
# Tipe data: float64
# Deskripsi: Skor penilaian dari kritikus film (Metascore).
#
# **10. Director**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Nama sutradara film.
#
# **11. Star1 **
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Pemeran utama pertama dalam film.
#
# **12. Star2**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Pemeran utama kedua dalam film.
#
# **13. Star3**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Pemeran utama ketiga dalam film.
#
# **14. Star4**
#
# Jumlah baris: 1000
# Tipe data: object
# Deskripsi: Pemeran utama keempat dalam film.
#
# **15. No_of_Votes**
#
# Jumlah baris: 1000
# Tipe data: int64
# Deskripsi: Jumlah voting atau suara yang diberikan oleh pengguna IMDb.
#
# **16. Gross**
#
# Jumlah baris: 831
# Tipe data: object
# Deskripsi: Pendapatan kotor film (box office).

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#                                               Poster_Link Series_Title  \
# count                                                1000         1000
# unique                                               1000          999
# top     https://m.media-amazon.com/images/M/MV5BMTY5OD...     Drishyam
# freq                                                    1            2
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#        Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# ...

# %% [markdown]
# **1. Count (Kelengkapan Data)**
#
# Berdasarkan dataset, total data film adalah 1000 baris. Maka dapat disimpulkan:
#
# - Certificate hilang 101 data (1000 - 899)
#
# - Meta_score hilang 157 data (1000 - 843)
#
# - Gross hilang 169 data (1000 - 831)
#
#
# ---
#
#
# Kesimpulan:
# Kolom Certificate, Meta_score, dan Gross mengandung missing values, sementara kolom lainnya sudah lengkap (1000 data).
#
# **2. Mean vs Median (Distribusi Data)**
#
# - Kolom IMDB_Rating
#
#   - Mean = 7,95
#
#   - Median = 7,90
#
# Nilai rata-rata sedikit lebih besar dari median, menunjukkan distribusi rating relatif stabil dan hampir simetris. Artinya, mayoritas film dalam dataset memiliki kualitas tinggi dengan rating yang tidak terlalu bervariasi ekstrem.
#
# - Kolom Meta_score
#
#   - Mean = 77,97
#
#   - Median = 79,00
#
# Median sedikit lebih besar dari mean, menunjukkan adanya beberapa film dengan skor kritikus rendah yang menurunkan nilai rata-rata.
#
#
# - Kolom No_of_Votes
#
#   - Mean = 273.692
#
#   - Median = 138.548
#
# Perbedaan yang cukup besar antara mean dan median menunjukkan adanya beberapa film dengan jumlah voting sangat tinggi yang menarik rata-rata ke atas.
#
#
# Kesimpulan: Secara keseluruhan, variabel No_of_Votes menunjukkan distribusi right-skewed, sedangkan IMDB_Rating relatif stabil dan mendekati distribusi normal.
#
#
# ---
#
#
# **3. Min dan Max (Validasi Logika)**
# - IMDB_Rating
#
#   - Min = 7,6
#
#   - Max = 9,3
#
# Rentang rating cukup sempit, menunjukkan semua film dalam dataset termasuk kategori film dengan kualitas tinggi.
#
# - Meta_score
#
#   - Min = 28
#
#   - Max = 100
#
# Terdapat perbedaan signifikan antara skor terendah dan tertinggi, menunjukkan variasi penilaian kritikus.
#
# - No_of_Votes
#
#   - Min = 25.088
#
#   - Max = 2.343.110
#
# Perbedaan yang sangat besar antara nilai minimum dan maksimum menunjukkan adanya film yang sangat populer dibandingkan yang lain.
#
# Kesimpulan:
# Rentang nilai voting yang sangat lebar wajar terjadi karena film blockbuster biasanya mendapatkan jutaan suara, sedangkan film lama atau niche memperoleh lebih sedikit voting.
#
#
#
# ---
#
#
# **4. Standar Deviasi (Std) – Variabilitas Data**
# - IMDB_Rating
#
#   - Mean = 7,95
#
#   - Std = 0,27
#
# Standar deviasi yang kecil menunjukkan bahwa rating antar film tidak terlalu jauh berbeda.
#
# - Meta_score
#
#   - Mean = 77,97
#
#   - Std = 12,38
#
# Menunjukkan variasi penilaian kritikus yang cukup besar dibanding rating pengguna.
#
# - No_of_Votes
#
#   - Mean = 273.692
#
#   - Std = 327.372
#
# Nilai standar deviasi yang lebih besar dari mean menunjukkan bahwa tingkat popularitas film sangat bervariasi, dari yang biasa saja hingga sangat populer.

# %% [markdown]
# ## **Verifikasi Kualitas Data**

# %% [markdown]
# ### **Data Type Check**

# %% [markdown]
# Dapat dilihat di bawah ini, kolom Released_Year masih bertipe data object, seharusnya kolom ini bertipe data numerik (integer) karena berisi tahun rilis film. Selain itu, kolom Runtime dan Gross juga masih bertipe object, padahal seharusnya bertipe numerik agar dapat dilakukan analisis statistik dengan tepat.
#
# Selain kolom tersebut, semua kolom lainnya sudah memiliki tipe data yang sesuai dengan karakteristik datanya masing-masing.

# %%
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# **1. Poster Link**
#
# Pada kolom Poster_Link memiliki format URL yang konsisten dan tidak ditemukan perbedaan struktur penulisan, sehingga tidak terdapat inconsistent values pada kolom ini.

# %%
df['Poster_Link'].unique()
# Out:
# array(['https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg',
#        'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg',
#        'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#        'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg',
#        'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg',
#        'https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg',
# ...

# %% [markdown]
# **2. Series Title**
#
# Pada kolom Series Title berisi data kategorikal berupa judul film dalam format teks. Berdasarkan hasil pengecekan nilai unik, tidak ditemukan perbedaan tipe data maupun format struktur penulisan. Oleh karena itu, tidak terdapat inconsistent values secara struktural pada kolom ini.

# %%
df['Series_Title'].unique()
# Out:
# array(['The Shawshank Redemption', 'The Godfather', 'The Dark Knight',
#        'The Godfather: Part II', '12 Angry Men',
#        'The Lord of the Rings: The Return of the King', 'Pulp Fiction',
#        "Schindler's List", 'Inception', 'Fight Club',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'Forrest Gump', 'Il buono, il brutto, il cattivo',
#        'The Lord of the Rings: The Two Towers', 'The Matrix',
#        'Goodfellas', 'Star Wars: Episode V - The Empire Strikes Back',
#        "One Flew Over the Cuckoo's Nest", 'Hamilton', 'Gisaengchung',
#        'Soorarai Pottru', 'Interstellar', 'Cidade de Deus',
#        'Sen to Chihiro no kamikakushi', 'Saving Private Ryan',
#        'The Green Mile', 'La vita è bella', 'Se7en',
#        'The Silence of the Lambs', 'Star Wars', 'Seppuku',
#        'Shichinin no samurai', "It's a Wonderful Life", 'Joker',
#        'Whiplash', 'The Intouchables', 'The Prestige', 'The Departed',
# ...

# %% [markdown]
# **3. Released Year**
#
# Pada kolom Released Year berisi data tahun rilis film, namun ditemukan nilai yang tidak sesuai yaitu “PG”. Nilai tersebut tidak merepresentasikan tahun, sehingga termasuk inconsistent value.

# %%
df['Released_Year'].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %% [markdown]
# **4. Certificate**
#
# Pada kolom Certificate berisi klasifikasi usia film dengan berbagai format penulisan seperti rating bioskop, rating televisi, angka, serta nilai kosong (NaN). Terdapat variasi format yang berbeda sehingga termasuk inconsistent values.

# %%
df['Certificate'].unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %% [markdown]
# **5. Runtime**
#
# Pada kolom Runtime memiliki format yang konsisten berupa angka yang diikuti satuan “min”. Namun, karena masih mengandung teks, tipe data terbaca sebagai object sehingga perlu dilakukan transformasi menjadi numerik agar dapat digunakan dalam analisis lebih lanjut.

# %%
df['Runtime'].unique()
# Out:
# array(['142 min', '175 min', '152 min', '202 min', '96 min', '201 min',
#        '154 min', '195 min', '148 min', '139 min', '178 min', '161 min',
#        '179 min', '136 min', '146 min', '124 min', '133 min', '160 min',
#        '132 min', '153 min', '169 min', '130 min', '125 min', '189 min',
#        '116 min', '127 min', '118 min', '121 min', '207 min', '122 min',
#        '106 min', '112 min', '151 min', '150 min', '155 min', '119 min',
#        '110 min', '88 min', '137 min', '89 min', '165 min', '109 min',
#        '102 min', '87 min', '126 min', '147 min', '117 min', '181 min',
#        '149 min', '105 min', '164 min', '170 min', '98 min', '101 min',
#        '113 min', '134 min', '229 min', '115 min', '143 min', '95 min',
#        '104 min', '123 min', '131 min', '108 min', '81 min', '99 min',
#        '114 min', '129 min', '228 min', '128 min', '103 min', '107 min',
#        '68 min', '138 min', '156 min', '167 min', '163 min', '186 min',
# ...

# %% [markdown]
# **6. Genre**
#
# Pada kolom Genre memiliki format penulisan yang konsisten dengan pemisahan menggunakan tanda koma. Namun, setiap baris dapat berisi lebih dari satu genre dalam satu sel.

# %%
df['Genre'].unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History',
#        'Action, Adventure, Sci-Fi', 'Drama, Romance', 'Western',
#        'Action, Sci-Fi', 'Biography, Crime, Drama',
#        'Action, Adventure, Fantasy', 'Comedy, Drama, Thriller',
#        'Adventure, Drama, Sci-Fi', 'Animation, Adventure, Family',
#        'Drama, War', 'Crime, Drama, Fantasy', 'Comedy, Drama, Romance',
#        'Crime, Drama, Mystery', 'Crime, Drama, Thriller',
#        'Action, Drama, Mystery', 'Drama, Family, Fantasy', 'Drama, Music',
#        'Biography, Comedy, Drama', 'Drama, Mystery, Sci-Fi',
#        'Biography, Drama, Music', 'Crime, Mystery, Thriller',
#        'Animation, Adventure, Drama', 'Animation, Drama, War',
#        'Adventure, Comedy, Sci-Fi', 'Horror, Mystery, Thriller',
#        'Drama, Romance, War', 'Comedy, Drama, Family',
#        'Animation, Drama, Fantasy', 'Action, Biography, Drama',
# ...

# %% [markdown]
# **7. IMDB_Rating**
#
# Kolom IMDB Rating memiliki tipe data numerik (float) dengan rentang nilai yang konsisten dan tidak ditemukan perbedaan format maupun nilai yang tidak wajar, sehingga tidak terdapat inconsistent values pada kolom ini.

# %%
df['IMDB_Rating'].unique()
# Out:
# array([9.3, 9.2, 9. , 8.9, 8.8, 8.7, 8.6, 8.5, 8.4, 8.3, 8.2, 8.1, 8. ,
#        7.9, 7.8, 7.7, 7.6])

# %% [markdown]
# **8. Overview**
#
# Pada kolom Overview berisi deskripsi atau sinopsis film dalam bentuk teks. Format penulisan konsisten dan tidak ditemukan perbedaan struktur data, sehingga tidak terdapat inconsistent values pada kolom ini.

# %%
df['Overview'].unique()
# Out:
# array(['Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.',
#        "An organized crime dynasty's aging patriarch transfers control of his clandestine empire to his reluctant son.",
#        'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.',
#        'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.',
#        'A jury holdout attempts to prevent a miscarriage of justice by forcing his colleagues to reconsider the evidence.',
#        "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.",
# ...

# %% [markdown]
# **9. Meta score**
#
# Pada kolom Meta Score memiliki tipe data numerik (float) dengan rentang nilai yang wajar. Namun, ditemukan beberapa nilai yang kosong (NaN).

# %%
df['Meta_score'].unique()
# Out:
# array([ 80., 100.,  84.,  90.,  96.,  94.,  74.,  66.,  92.,  82.,  87.,
#         73.,  83.,  nan,  79.,  91.,  61.,  59.,  65.,  85.,  98.,  89.,
#         88.,  57.,  67.,  62.,  77.,  64.,  75.,  97.,  99.,  78.,  68.,
#         81.,  95.,  76.,  69.,  55.,  70.,  58.,  86.,  71.,  63.,  93.,
#         72.,  60.,  47.,  49.,  50.,  33.,  54.,  56.,  51.,  53.,  48.,
#         44.,  45.,  40.,  52.,  28.,  36.,  46.,  30.,  41.])

# %% [markdown]
# **10. Director**
#
# Pada kolom Director berisi nama sutradara dalam format teks dengan struktur penulisan yang konsisten. Tidak ditemukan perbedaan format maupun nilai yang tidak sesuai, sehingga tidak terdapat inconsistent values pada kolom ini.

# %%
df['Director'].unique()
# Out:
# array(['Frank Darabont', 'Francis Ford Coppola', 'Christopher Nolan',
#        'Sidney Lumet', 'Peter Jackson', 'Quentin Tarantino',
#        'Steven Spielberg', 'David Fincher', 'Robert Zemeckis',
#        'Sergio Leone', 'Lana Wachowski', 'Martin Scorsese',
#        'Irvin Kershner', 'Milos Forman', 'Thomas Kail', 'Bong Joon Ho',
#        'Sudha Kongara', 'Fernando Meirelles', 'Hayao Miyazaki',
#        'Roberto Benigni', 'Jonathan Demme', 'George Lucas',
#        'Masaki Kobayashi', 'Akira Kurosawa', 'Frank Capra',
#        'Todd Phillips', 'Damien Chazelle', 'Olivier Nakache',
#        'Roman Polanski', 'Ridley Scott', 'Tony Kaye', 'Bryan Singer',
#        'Luc Besson', 'Roger Allers', 'James Cameron',
#        'Giuseppe Tornatore', 'Isao Takahata', 'Alfred Hitchcock',
#        'Michael Curtiz', 'Charles Chaplin', 'Nadine Labaki', 'Can Ulkay',
#        'Gayatri', 'Makoto Shinkai', 'Nitesh Tiwari', 'Bob Persichetti',
# ...

# %% [markdown]
# **11. Star 1**
#
# Pada kolom Star 1 berisi nama pemeran utama dalam format teks yang konsisten. Tidak ditemukan perbedaan struktur penulisan maupun nilai yang tidak sesuai, sehingga tidak terdapat inconsistent values pada kolom ini.

# %%
df['Star1'].unique()
# Out:
# array(['Tim Robbins', 'Marlon Brando', 'Christian Bale', 'Al Pacino',
#        'Henry Fonda', 'Elijah Wood', 'John Travolta', 'Liam Neeson',
#        'Leonardo DiCaprio', 'Brad Pitt', 'Tom Hanks', 'Clint Eastwood',
#        'Lilly Wachowski', 'Robert De Niro', 'Mark Hamill',
#        'Jack Nicholson', 'Lin-Manuel Miranda', 'Kang-ho Song', 'Suriya',
#        'Matthew McConaughey', 'Kátia Lund', 'Daveigh Chase',
#        'Roberto Benigni', 'Morgan Freeman', 'Jodie Foster',
#        'Tatsuya Nakadai', 'Toshirô Mifune', 'James Stewart',
#        'Joaquin Phoenix', 'Miles Teller', 'Éric Toledano', 'Adrien Brody',
#        'Russell Crowe', 'Edward Norton', 'Kevin Spacey', 'Jean Reno',
#        'Rob Minkoff', 'Arnold Schwarzenegger', 'Philippe Noiret',
#        'Tsutomu Tatsumi', 'Michael J. Fox', 'Anthony Perkins',
#        'Humphrey Bogart', 'Charles Chaplin', 'Zain Al Rafeea',
#        'Erdem Can', 'Pushkar', 'Ryûnosuke Kamiki', 'Aamir Khan',
# ...

# %% [markdown]
# **12. Star2**
#
# Pada kolom Star 2 berisi nama pemeran pendukung dalam format teks yang konsisten. Tidak ditemukan perbedaan struktur penulisan maupun nilai yang tidak sesuai, sehingga tidak terdapat inconsistent values pada kolom ini.

# %%
df['Star2'].unique()
# Out:
# array(['Morgan Freeman', 'Al Pacino', 'Heath Ledger', 'Robert De Niro',
#        'Lee J. Cobb', 'Viggo Mortensen', 'Uma Thurman', 'Ralph Fiennes',
#        'Joseph Gordon-Levitt', 'Edward Norton', 'Ian McKellen',
#        'Robin Wright', 'Eli Wallach', 'Keanu Reeves', 'Ray Liotta',
#        'Harrison Ford', 'Louise Fletcher', 'Phillipa Soo', 'Lee Sun-kyun',
#        'Madhavan', 'Anne Hathaway', 'Alexandre Rodrigues',
#        'Suzanne Pleshette', 'Matt Damon', 'Michael Clarke Duncan',
#        'Nicoletta Braschi', 'Brad Pitt', 'Anthony Hopkins',
#        'Akira Ishihama', 'Takashi Shimura', 'Donna Reed', 'J.K. Simmons',
#        'François Cluzet', 'Hugh Jackman', 'Thomas Kretschmann',
#        'Joaquin Phoenix', 'Edward Furlong', 'Gabriel Byrne',
#        'Gary Oldman', 'Matthew Broderick', 'Linda Hamilton',
#        'Enzo Cannavale', 'Ayano Shiraishi', 'Christopher Lloyd',
#        'Charles Bronson', 'Janet Leigh', 'Ingrid Bergman',
# ...

# %% [markdown]
# **13. Star 3**
#
# Pada kolom Star 3 berisi nama pemeran pendukung dalam format teks yang konsisten. Tidak ditemukan nilai yang tidak sesuai maupun perbedaan struktur penulisan, sehingga tidak terdapat inconsistent values pada kolom ini. Kolom ini telah sesuai dan tidak memerlukan proses pembersihan lanjutan.

# %%
df['Star3'].unique()
# Out:
# array(['Bob Gunton', 'James Caan', 'Aaron Eckhart', 'Robert Duvall',
#        'Martin Balsam', 'Ian McKellen', 'Samuel L. Jackson',
#        'Ben Kingsley', 'Elliot Page', 'Meat Loaf', 'Orlando Bloom',
#        'Gary Sinise', 'Lee Van Cleef', 'Viggo Mortensen',
#        'Laurence Fishburne', 'Joe Pesci', 'Carrie Fisher',
#        'Michael Berryman', 'Leslie Odom Jr.', 'Cho Yeo-jeong',
#        'Paresh Rawal', 'Jessica Chastain', 'Leandro Firmino',
#        'Miyu Irino', 'Tom Sizemore', 'David Morse', 'Giorgio Cantarini',
#        'Kevin Spacey', 'Lawrence A. Bonney', 'Shima Iwashita',
#        'Keiko Tsushima', 'Lionel Barrymore', 'Zazie Beetz',
#        'Melissa Benoist', 'Omar Sy', 'Scarlett Johansson',
#        'Jack Nicholson', 'Frank Finlay', 'Connie Nielsen',
#        "Beverly D'Angelo", 'Chazz Palminteri', 'Natalie Portman',
#        'Jeremy Irons', 'Edward Furlong', 'Antonella Attili',
#        'Akemi Yamaguchi', 'Lea Thompson', 'Claudia Cardinale',
# ...

# %% [markdown]
# **14. Star 4**
#
# Pada kolom Star 4 berisi nama pemeran pendukung dalam format teks (object) yang konsisten. Tidak ditemukan perbedaan struktur penulisan maupun nilai yang tidak sesuai. Secara keseluruhan, kolom ini tidak memiliki inconsistent values dan tidak memerlukan proses pembersihan data tambahan.

# %%
df['Star4'].unique()
# Out:
# array(['William Sadler', 'Diane Keaton', 'Michael Caine', 'John Fiedler',
#        'Orlando Bloom', 'Bruce Willis', 'Caroline Goodall',
#        'Ken Watanabe', 'Zach Grenier', 'Sean Bean', 'Sally Field',
#        'Aldo Giuffrè', 'Carrie-Anne Moss', 'Lorraine Bracco',
#        'Billy Dee Williams', 'Peter Brocco', 'Renée Elise Goldsberry',
#        'Choi Woo-sik', 'Aparna Balamurali', 'Mackenzie Foy',
#        'Matheus Nachtergaele', 'Rumi Hiiragi', 'Edward Burns',
#        'Bonnie Hunt', 'Giustino Durano', 'Andrew Kevin Walker',
#        'Kasi Lemmons', 'Alec Guinness', 'Tetsurô Tanba',
#        'Yukiko Shimazaki', 'Thomas Mitchell', 'Frances Conroy',
#        'Paul Reiser', 'Anne Le Ny', 'Mark Wahlberg', 'Emilia Fox',
#        'Oliver Reed', 'Jennifer Lien', 'Stephen Baldwin', 'Danny Aiello',
#        'James Earl Jones', 'Robert Patrick', 'Isa Danieli',
#        'Yoshiko Shinohara', 'Crispin Glover', 'Jason Robards',
# ...

# %% [markdown]
# **15. No of Votes**
#
# Pada kolom No of Votes berisi jumlah suara penonton dalam bentuk angka yang konsisten. Tidak ditemukan nilai yang tidak sesuai maupun format yang berbeda.

# %%
df['No_of_Votes'].unique()
# Out:
# array([2343110, 1620367, 2303232, 1129952,  689845, 1642758, 1826188,
#        1213505, 2067042, 1854740, 1661481, 1809221,  688390, 1485555,
#        1676426, 1020727, 1159315,  918088,   55291,  552778,   54995,
#        1512360,  699256,  651376, 1235804, 1147794,  623629, 1445096,
#        1270197, 1231473,   42004,  315744,  405801,  939252,  717585,
#         760360, 1190259, 1189773,  729603, 1341460, 1034705,  991208,
#        1035236,  942045,  995506,  230763,  235231, 1058081,  302844,
#         604211,  522093,  217881,  167839,   62635,   34112,   28401,
#         194838,  156479,  375110,  809955,  834477,  384171, 1357682,
#        1516346,  344445,  168895,  999790,  358685,  515451, 1125712,
#         343171,  311365,  884112,  898237,  606398,  787806,   30273,
#          34357,  450474,  108862,  178092,  444074,  201632,  203150,
#         425844,   27793,   71875,   30722,  281623,  220002,  150023,
# ...

# %% [markdown]
# **16. Gross**
#
# Pada kolom Gross masih bertipe data object karena terdapat tanda koma (,) sebagai pemisah ribuan. Selain itu, ditemukan beberapa nilai yang kosong (NaN).

# %%
df['Gross'].unique()
# Out:
# array(['28,341,469', '134,966,411', '534,858,444', '57,300,000',
#        '4,360,000', '377,845,905', '107,928,762', '96,898,818',
#        '292,576,195', '37,030,102', '315,544,750', '330,252,182',
#        '6,100,000', '342,551,365', '171,479,930', '46,836,394',
#        '290,475,067', '112,000,000', nan, '53,367,844', '188,020,017',
#        '7,563,397', '10,055,859', '216,540,909', '136,801,374',
#        '57,598,247', '100,125,643', '130,742,922', '322,740,140',
#        '269,061', '335,451,311', '13,092,000', '13,182,281', '53,089,891',
#        '132,384,315', '32,572,577', '187,705,427', '6,719,864',
#        '23,341,568', '19,501,238', '422,783,777', '204,843,350',
#        '11,990,401', '210,609,762', '5,321,508', '32,000,000',
#        '1,024,560', '163,245', '19,181', '1,661,096', '5,017,246',
#        '12,391,761', '190,241,310', '858,373,000', '678,815,482',
#        '209,726,015', '162,805,434', '448,139,099', '6,532,908',
# ...

# %% [markdown]
# ### **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                Null Ratio in %
# Poster_Link                0.0
# Series_Title               0.0
# Released_Year              0.0
# Certificate               10.1
# Runtime                    0.0
# Genre                      0.0
# IMDB_Rating                0.0
# Overview                   0.0
# Meta_score                15.7
# Director                   0.0
# Star1                      0.0
# Star2                      0.0
# Star3                      0.0
# Star4                      0.0
# No_of_Votes                0.0
# Gross                     16.9

# %% [markdown]
# - Certificate
# Memiliki missing values sekitar 10.1%, yang dimana jumlah ini masih tergolong rendah. Nilai kosong pada kolom ini kemungkinan disebabkan karena tidak semua film memiliki klasifikasi usia yang tercantum. Kolom ini dapat ditangani atau dihapus.
#
# - Meta_score
# Memiliki missing values sekitar 15.7%, yang dimana persentase ini cukup signifikan dibanding kolom lainnya. Hal ini kemungkinan terjadi karena tidak semua film memiliki penilaian dari kritikus. Oleh karena itu, kolom ini perlu ditangani atau dihapus.

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Dataset tidak memiliki duplicated values, sehingga tidak diperlukan proses penghapusan data duplikat.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %% [markdown]
# ### **Outliers**

# %% [markdown]
# Terlihat pada kolom:
#
# - No_of_Votes
#
#   Dengan persentase sebesar 6.7%, merupakan kolom dengan jumlah outliers tertinggi.
#
#
# - IMDB_Rating
#
#   Dengan persentase sebesar 1.3%.
#
# - Meta_score
#
#   Dengan persentase sebesar 0.7% (di bawah 1%), merupakan kolom dengan jumlah outliers paling rendah.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom        Persentase Outliers
# IMDB_Rating                  1.3
# Meta_score                   0.7
# No_of_Votes                  6.7

# %% [markdown]
# Titik-titik di bawah ini menunjukkan adanya data dengan jumlah voting yang jauh lebih tinggi dibandingkan sebagian besar film lainnya.
#
# Hal ini sesuai dengan hasil perhitungan sebelumnya, dimana kolom No_of_Votes memiliki persentase outliers sebesar 6.7%, yang merupakan yang tertinggi dibandingkan kolom lainnya.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['No_of_Votes'])
plt.title('Boxplot of No_of_Votes')
plt.ylabel('No_of_Votes')
plt.show()

# %% [markdown]
#  Boxplot pada  IMDB_Rating menunjukkan adanya film dengan rating yang jauh lebih tinggi dibandingkan mayoritas film lainnya.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['IMDB_Rating'])
plt.title('IMDB_Rating')
plt.ylabel('IMDB_Rating')
plt.show()

# %% [markdown]
# Boxplot dibawah ini menunjukkan adanya titik-titik yang berarti terdapat film dengan meta score jauh lebih rendah dibandingkan mayoritas film lainnya. Hal ini sesuai dengan hasil perhitungan sebelumnya, di mana kolom Meta_score memiliki persentase outliers terendah.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Meta_score'])
plt.title('Meta_score')
plt.ylabel('Meta_score')
plt.show()

# %% [markdown]
# ## **Eksplorasi Data (EDA)**

# %% [markdown]
# ### **Comparison/Perbandingan**

# %% [markdown]
# Comparison dalam analisis IMDb Movies Dataset digunakan untuk membandingkan nilai antar kategori agar terlihat mana yang lebih unggul. Pada grafik Top 10 Genre dengan Rata-rata IMDb Rating Tertinggi, terlihat bahwa genre Animation, Drama, War memiliki rata-rata rating lebih tinggi dibanding genre lain seperti Adventure, Mystery, Thriller. Hal ini menunjukkan bahwa setiap genre memiliki kualitas yang berbeda menurut penilaian penonton.
# Analisis perbandingan seperti ini penting karena membantu mengidentifikasi kategori yang menonjol, baik dari sisi rating maupun votes. Dengan begitu, kita bisa mengetahui genre atau aktor mana yang lebih konsisten menghasilkan film berkualitas tinggi, sehingga dapat dijadikan acuan dalam pengambilan keputusan.

# %%
rating_genre = df.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False)

top10_genre = rating_genre.head(10)

plt.figure(figsize=(10,6))
sns.barplot(y=top10_genre.index, x=top10_genre.values, palette='viridis')
plt.title('Top 10 Genre dengan Rata-rata IMDB Rating Tertinggi')
plt.xlabel('Rata-rata IMDB Rating')
plt.ylabel('Genre')
plt.show()
# Out:
# /tmp/ipykernel_419/2682166840.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top10_genre.index, x=top10_genre.values, palette='viridis')

# %% [markdown]
# ### **Composition/Komposisi**

# %% [markdown]
# Composition pada analisis IMDb Movies Dataset digunakan untuk melihat proporsi atau kontribusi suatu kategori terhadap keseluruhan data. Melalui pie chart Top 3 Aktor Utama (Star1) Berdasarkan Total Votes (No_of_Votes), terlihat bahwa Leonardo DiCaprio menyumbang 37% dari total suara penonton, Tom Hanks 32.2%, dan Christian Bale 30.7%. Hal ini menunjukkan bahwa ketiga aktor tersebut memiliki daya tarik besar dalam menarik penonton untuk memberikan rating. Analisis komposisi seperti ini membantu industri perfilman memahami aktor atau genre mana yang paling dominan dalam memengaruhi popularitas film, sehingga dapat dijadikan pertimbangan dalam pemilihan pemain maupun strategi produksi.

# %%
votes_actor = df.groupby('Star1')['No_of_Votes'].sum().sort_values(ascending=False)

top5_actor = votes_actor.head(3)

plt.figure(figsize=(10,8))
top5_actor.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Top 3 Aktor Utama Berdasarkan Total Votes')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### **Distribution/Distribusi**

# %% [markdown]
# Distribution dalam analisis IMDb Movies Dataset digunakan untuk melihat bagaimana data tersebar pada suatu variabel. Pada grafik Distribusi IMDb Rating, terlihat bahwa mayoritas film memiliki rating yang terkonsentrasi di kisaran 7.5–8.0. Hal ini menunjukkan bahwa sebagian besar film dalam dataset dinilai cukup tinggi oleh penonton, sementara hanya sedikit film yang memiliki rating sangat rendah atau sangat tinggi.
# Analisis distribusi seperti ini penting karena membantu memahami pola umum dalam data. Dengan melihat sebaran rating, kita bisa mengetahui standar kualitas film menurut penonton, apakah cenderung tinggi, sedang, atau rendah. Distribusi juga dapat digunakan untuk mendeteksi adanya outlier, yaitu film dengan rating yang jauh berbeda dari mayoritas.

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['IMDB_Rating'], bins=20, kde=True, color='skyblue')
plt.title('Distribusi IMDb Rating')
plt.xlabel('IMDb Rating')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ### **Relationship/Hubungan**

# %% [markdown]
# Relationship dalam analisis IMDb Movies Dataset digunakan untuk melihat hubungan antar variabel, apakah satu variabel memengaruhi atau berkaitan dengan variabel lain. Contohnya, pada heatmap Korelasi antara Jumlah Votes dan IMDb Rating, terlihat nilai korelasi sebesar 0.49. Angka ini menunjukkan adanya hubungan positif sedang antara jumlah votes dengan rating, semakin banyak penonton yang memberikan suara, cenderung rating film juga lebih tinggi, meskipun tidak selalu kuat.
# Analisis relationship seperti ini penting karena membantu memahami keterkaitan antara popularitas dan kualitas. Dengan mengetahui adanya korelasi, industri perfilman bisa menilai bahwa film yang populer (banyak votes) umumnya juga dianggap berkualitas oleh penonton. Namun, karena korelasinya tidak terlalu tinggi, hal ini juga menegaskan bahwa popularitas tidak selalu identik dengan kualitas

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    data=df[['No_of_Votes', 'IMDB_Rating']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f'
)
plt.title('Korelasi antara Jumlah Votes dan IMDb Rating')
plt.show()

# %% [markdown]
# ## **Menyimpan Dataset**

# %%
df.to_csv('/content/drive/MyDrive/AVD/imdb_top_1000.csv', index=False)

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# Tahap ini merupakan proses mengolah dan membersihkan data sebelum digunakan untuk analisis agar memastikan data menjadi lebih sesuai untuk di analisis serta memastikan kualitas data yang memadai.

# %% [markdown]
# ### **Data Type**

# %% [markdown]
# Tipe data (data type) adalah klasifikasi atau atribut yang menentukan jenis nilai yang dapat ditampung oleh suatu variabel dan bagaimana data tersebut diproses, disimpan, atau dimanipulasi oleh program komputer. Perintah di bawah ini digunakan untuk mengecek tipe data dari setiap kolom yang ada di dalam DataFrame.

# %%
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %% [markdown]
# **1. Released Year**

# %% [markdown]
# Perintah di bawah ini merupakan perintah untuk mengubah tipe data menjadi numerik. Hal ini dilakukan karena pada kolom Released_Year merupakan kolom yang berisi tahun rilis suatu film, yang mana seharusnya tipe data di dalam kolom ini adalah numerik karena berisikan angka numerik.

# %%
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')

# %%
df['Released_Year'] = df['Released_Year'].astype('Int64')

# %% [markdown]
# Setelah dilakukan penanganan tipe data. Tipe data berhasil diubah menjadi bentuk numerik.

# %%
df['Released_Year'].head()
# Out:
# 0    1994
# 1    1972
# 2    2008
# 3    1974
# 4    1957
# Name: Released_Year, dtype: Int64

# %% [markdown]
# **2. Runtime**

# %% [markdown]
# Perintah di bawah ini merupakan perintah untuk menghapus kata "min" agar hanya tersisa angka saja pada kolom Runtime. Hal ini dilakukan agar setelah memasukkan kode untuk mengubah tipe data menjadi bentuk numerik, data tidak hilang atau data yang muncul adalah Nan atau <NA>. Sehingga agar kolom Runtime dapat di ubah tipe data menjadi numerik (karena Runtime adalah durasi waktu) maka dihapuslah kata min agar data masih bisa terbaca.

# %%
df['Runtime'] = df['Runtime'].str.replace(' min', '')

# %% [markdown]
# Perintah di bawah ini merupakan perintah untuk mengubah tipe data menjadi numerik.

# %%
df['Runtime'] = pd.to_numeric(df['Runtime'], errors='coerce')

# %%
df['Runtime'] = df['Runtime'].astype('Int64')

# %% [markdown]
# Setelah dilakukan penanganan tipe data. Tipe data berhasil diubah menjadi bentuk numerik.

# %%
df['Runtime'].head()
# Out:
# 0    142
# 1    175
# 2    152
# 3    202
# 4     96
# Name: Runtime, dtype: Int64

# %% [markdown]
# **3. Gross**

# %% [markdown]
# Perintah di bawah ini merupakan perintah untuk menghapus koma agar hanya tersisa angka saja pada kolom Gross. Sama seperti sebelumnya, Hal ini dilakukan agar setelah memasukkan kode untuk mengubah tipe data menjadi bentuk numerik, data tidak hilang atau data yang muncul adalah Nan. Sehingga agar kolom Gross dapat di ubah tipe data menjadi numerik (karena Gross adalah hasil penjualan film) maka dihapuslah tanda koma agar data bersih dan bisa terbaca. Selain itu adanya tanda koma itu dianggap teks/string.

# %%
df['Gross'] = df['Gross'].str.replace(',', '')

# %% [markdown]
# Perintah di bawah ini merupakan perintah untuk mengubah tipe data menjadi numerik.

# %%
df['Gross'] = pd.to_numeric(df['Gross'], errors='coerce')

# %%
df['Gross'] = df['Gross'].astype('Int64')

# %% [markdown]
# Setelah dilakukan penanganan tipe data. Tipe data berhasil diubah menjadi bentuk numerik.

# %%
df['Gross'].head()
# Out:
# 0     28341469
# 1    134966411
# 2    534858444
# 3     57300000
# 4      4360000
# Name: Gross, dtype: Int64

# %% [markdown]
# Setelah melakukan penangan terhadap tipe data, terlihat di bawah ini bahwa tipe data telah berhasil diubah.

# %%
df.dtypes
# Out:
# Poster_Link       object
# Series_Title      object
# Released_Year      Int64
# Certificate       object
# Runtime            Int64
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross              Int64
# dtype: object

# %% [markdown]
# ### **Inconsistent Values**

# %% [markdown]
# Inconsistent Values adalah kondisi di mana data dalam suatu kolom memiliki format atau standar yang berbeda dari aturan yang seharusnya berlaku pada kolom tersebut.

# %% [markdown]
# **1. Certificate**

# %% [markdown]
# Di bawah ini merupakan perintah untuk penanganan pada kolom certificate yang tidak konsisten. Incosistent Values pada kolom ini disebabkan oleh pencampuran berbagai standar rating film dari negara yang berbeda, seperti standar Amerika (MPA) dengan kode G/PG dan standar India (CBFC) dengan kode U/UA. Selain itu, terdapat masalah redundansi di mana satu kategori yang sama ditulis dengan format berbeda, contohnya penggunaan UA dan U/A yang membuat data terbaca sebagai dua kategori yang berbeda. Perintah di bawah ini diterapkan untuk mengatasi masalah tersebut, yaitu dengan melakukan standarisasi data melalui metode mapping.

# %%
df['Certificate'] = df['Certificate'].replace({
    'U/A': 'UA',
    'G': 'U',
    'TV-MA': 'A',
    'R': 'A',
    '16': 'PG-13',
    'TV-14': 'PG-13',
    'Passed': 'Unrated',
    'Approved': 'Unrated',
    'GP': 'Unrated'
})

for col in ['Certificate']:
    print(df[col].unique())
# Out:
# ['A' 'UA' 'U' 'PG-13' nan 'PG' 'Unrated' 'TV-PG']

# %% [markdown]
# Setelah dilakukan penanganan pada kolom Certificate, terlihat bahwa jumlah kategori kini menjadi lebih ringkas yang menandakan bahwa data sudah lebih konsisten.

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Missing Values merupakan sebuah kondisi dimana data hilang atau tidak terbaca. Sebelumnya telah dilakukan pengecekan terhadap dataset untuk melihat seberapa besar rasio presentase missing values atau data yang hilang.
#
# Kolom Gross (16.9%) dan Meta_score (15.7%): Kedua kolom ini memiliki tingkat kehilangan data yang paling tinggi. Hal ini cukup krusial karena Gross berkaitan dengan pendapatan film dan Meta_score berkaitan dengan penilaian kritikus. Tingginya angka ini menunjukkan adanya keterbatasan informasi finansial dan ulasan kritikus pada sumber data asli, sehingga perlu penanganan khusus (seperti pengisian nilai rata-rata atau penghapusan data).
#
# Kolom Certificate (10.1%): Terdapat sekitar 10% data film yang tidak memiliki label rating usia. Hal ini menjelaskan mengapa muncul nilai nan pada output kodingan sebelumnya. Nilai kosong ini kemungkinan besar berasal dari film-film independen atau film internasional yang belum mendapatkan klasifikasi rating resmi.
#
# Kolom Released_Year (0.1%): Tingkat kehilangan data di kolom ini sangat kecil.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                Null Ratio in %
# Poster_Link                0.0
# Series_Title               0.0
# Released_Year              0.1
# Certificate               10.1
# Runtime                    0.0
# Genre                      0.0
# IMDB_Rating                0.0
# Overview                   0.0
# Meta_score                15.7
# Director                   0.0
# Star1                      0.0
# Star2                      0.0
# Star3                      0.0
# Star4                      0.0
# No_of_Votes                0.0
# Gross                     16.9

# %% [markdown]
# **1. Gross**

# %% [markdown]
# Kolom Gross memiliki tingkat data hilang (missing values) yang cukup signifikan, yaitu sebesar 16.9%.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Gross'], bins=20, kde=True)
plt.title('Distribusi Gross')
plt.xlabel('Gross')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Melihat distribusi data penduduk di atas, terlihat bahwa distribusi data pendapatan atau gorss tidak merata atau cenderung miring ke kanan (right-skewed), di mana terdapat banyak nilai ekstrem (outliers) dari segelintir film dengan pendapatan yang sangat tinggi. metode imputasi median dipilih sebagai langkah yang paling aman agar nilai pengisi data kosong tidak menyimpang jauh dari karakteristik asli dataset. Di bawah ini merupakan penanganan Missing Values pada kolom 'Gross'.

# %%
df['Gross'] = df['Gross'].fillna(df['Gross'].dropna().median())

# %% [markdown]
# **2. Meta_Score**

# %% [markdown]
# Kolom Meta_Score memiliki tingkat data hilang (missing values) yang cukup signifikan, yaitu sebesar 15.7%.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Meta_score'], bins=20, kde=True)
plt.title('Distribusi Meta_score')
plt.xlabel('Meta_score')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berdasarkan visualisasi histogram di atas, terlihat bahwa data memiliki distribusi yang cenderung mendekati distribusi normal (simetris), meskipun ada sedikit kemiringan ke kiri (negative skew). Sebagian besar data berkumpul di rentang skor 60 hingga 90, yang menunjukkan bahwa mayoritas film dalam dataset ini memiliki penilaian kritikus yang cukup stabil dan berada pada rentang yang serupa.Karena tidak adanya nilai ekstrem (outliers) yang mencolok seperti pada data pendapatan, maka penggunaan Mean (rata-rata) sebagai metode imputasi. Di bawah ini merupakan penanganan Missing Values pada kolom 'Meta_score'.

# %%
df['Meta_score'] = df['Meta_score'].fillna(df['Meta_score'].dropna().median())

# %% [markdown]
# **3. Certificate**

# %% [markdown]
# Berdasarkan hasil observasi, ditemukan adanya pola di mana film yang memiliki missing values pada kolom Certificate cenderung juga memiliki missing values pada kolom Gross. Mengingat persentase data yang hilang pada Certificate hanya sekitar 10.1%, diputuskan untuk melakukan penghapusan atau drop. Metode ini dipilih untuk menjaga integritas analisis, penggunaan modus untuk mengisi kolom Certificate sangat dihindari karena berisiko menciptakan bias klasifikasi. Sebagai contoh, film dengan konten dewasa yang datanya hilang dapat secara tidak sengaja terlabeli sebagai film 'Semua Umur' (U) jika mengikuti nilai mayoritas dataset.

# %%
df = df.drop('Certificate', axis=1)

# %% [markdown]
# **4. Released Year**

# %% [markdown]
# Kolom Released Year memiliki tingkat data hilang (missing values) sebesar 0.1%. Karena melihat presentasenya yang rendah dan untuk tahun sendiri tidak dapat dilakukan imputasi sama seperti kolom certificate. Maka dilakukan penghapusan atau drop untuk penanganannya.

# %%
df['Released_Year'] = df['Released_Year'].replace('PG', '1995')

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Dataset tidak memiliki duplicated values, sehingga tidak diperlukan proses penghapusan atau penanganan data duplikat.

# %% [markdown]
# ### **Outliers**

# %% [markdown]
# Outliers merupakan nilai yang jauh berbeda dari nilai yang lain.

# %% [markdown]
# **1. Gross**
#
# Ditemukan persentase outliers sebesar 12.5% pada kolom pendapatan, namun diputuskan untuk tetap menggunakan data asli dengan mengabaikan nilai outliers. Alasannya, nilai pendapatan yang sangat tinggi merupakan bukti nyata kesuksesan film yang menjadi target utama industri, sehingga menghapus data ini akan menghilangkan wawasan krusial mengenai potensi keuntungan maksimal yang bisa dicapai oleh sebuah formula film.
#
# **2. No_of_Votes**
#
# Ditemukan persentase outliers sebesar 6.7% yang mencerminkan tingkat keterlibatan massa yang luar biasa, sehingga diputuskan untuk mengabaikan nilai outliers ini. Hal ini dilakukan untuk menjaga integritas data mengenai popularitas film-film legendaris, agar industri dapat mengukur sejauh mana sebuah karya mampu menarik perhatian penonton secara masif tanpa adanya pemotongan data.
#
# **3. Meta_score**
#
# Persentase outliers pada kolom ini sebesar 3,1%, sehingga tindakan yang diambil adalah membiarkan data dengan mengabaikan nilai outliersnya. Hal ini dilakukan karena rentang nilai skor kritik (0-100) sudah bersifat stabil secara alami, sehingga data asli tetap digunakan guna menjamin perbandingan yang akurat antara selera pasar dengan penilaian teknis dari para kritikus profesional.
#
# **4. Runtime**
#
# Persentase outliers sebesar 2,9% pada durasi film yang sangat panjang, dan terhadap kolom ini dilakukan penanganan imputasi dengan metode capping. Alasannya adalah untuk menormalisasi durasi yang terlalu ekstrim agar tidak merusak perhitungan rata-rata durasi ideal, sehingga hasil analisis dapat memberikan rekomendasi durasi yang lebih efisien secara biaya produksi dan nyaman bagi penonton bioskop umum.
#
# **5. IMDb_Rating**
#
# Kolom ini memiliki persentase outliers sebesar 1,3%, dan terhadap data tersebut akan membiarkannya dengan mengabaikan nilai outliers . Karena tujuan bisnis adalah mengidentifikasi karakteristik film yang paling disukai audiens, maka nilai rating yang sangat tinggi merupakan objek penelitian utama yang valid untuk melihat standar kepuasan penonton tertinggi.
#
# **6. Released_Year**
#
# Ditemukan persentase outliers sebesar 0,7% yang merepresentasikan film-film dari era klasik. Terhadap data ini, diputuskan untuk mempertahankan data asli dengan mengabaikan nilai outliers guna menjaga histori kesuksesan film lintas zaman, sehingga industri dapat mempelajari apakah elemen daya tarik film lama masih relevan dengan selera penonton modern.

# %%
columns_to_impute = ["Runtime"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Perintah di atas merupakan perintah untuk melakukan metode capping pada kolom runtime guna menormalisasi durasi yang terlalu ekstrim agar tidak merusak perhitungan rata-rata durasi ideal, sehingga hasil analisis dapat memberikan rekomendasi durasi yang lebih efisien secara biaya produksi dan nyaman bagi penonton bioskop umum.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom          Persentase Outliers
# Released_Year                  0.7
# Runtime                        0.0
# IMDB_Rating                    1.3
# Meta_score                     3.1
# No_of_Votes                    6.7
# Gross                         12.5

# %% [markdown]
# Setelah di lakukan imputasi pada kolom runtime dapat dilihat presentase nilai outliers pada kolom runtime telah menjadi 0.0%

# %% [markdown]
# ## **Data Construction**

# %% [markdown]
# Construct data merupakan kegiatan untuk menciptakan firtur (features) baru dari data yang ada maupun mengubah data agar sesuai dengan kebutuhan analisis atau data mining yang akan digunakan.

# %% [markdown]
# **1. Genre**
#
# Pada dataset asli, kolom Genre memiliki format multi-label (satu film memiliki beberapa genre sekaligus). Untuk mempermudah analisis preferensi penonton secara spesifik, dilakukan konstruksi data dengan mengekstraksi genre pertama sebagai Main_Genre. Hal ini didasarkan pada asumsi industri bahwa genre yang disebutkan pertama merupakan representasi klasifikasi utama dari sebuah film, sehingga memudahkan dalam pemetaan korelasi antara genre dominan terhadap kesuksesan komersial (Gross) dan tingkat kepuasan penonton (IMDB_Rating)

# %%
df['Main_Genre'] = df['Genre'].apply(lambda x: x.split(',')[0].strip())

# %% [markdown]
# Perintah  di atas merupakan perintah untuk melakukan ekstrasi genre pertama sebagai main genre. Dugunakan elemen pertama dari list hasil genre untuk dijadikan main genre.

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title  Released_Year  Runtime  \
# 0    The Shawshank Redemption           1994      142
# 1               The Godfather           1972      175
# 2             The Dark Knight           2008      152
# 3      The Godfather: Part II           1974      188
# ...

# %% [markdown]
# ## **Data Reduction**

# %% [markdown]
# Data Reduction merupakan metode yang digunakan dalam data mining untuk mengurangi ukuran dataset tetapi dengan tetap menjaga informasi penting.

# %% [markdown]
# **1. Poster Film**
#
# Kolom ini dihapus karena hanya berisi URL gambar poster film yang merupakan data tidak terstruktur. Informasi ini tidak memiliki nilai numerik atau kategorikal yang dapat diolah untuk mencari korelasi terhadap kesuksesan finansial maupun kualitas sebuah film.
#
# **2. Genre**
#
# Kolom Genre asli dihapus karena telah dilakukan proses Data Construction menjadi variabel Main_Genre. Reduksi ini bertujuan untuk menghilangkan redundansi data dan memastikan bahwa setiap entitas film hanya memiliki satu klasifikasi genre tunggal yang konsisten, sehingga mempermudah proses visualisasi dan perbandingan antar kategori.
#
# **3. Overview**
#
# Kolom ini berisi sinopsis atau ringkasan alur cerita film dalam format teks naratif. Karena analisis ini berfokus pada statistik deskriptif dan pola keberhasilan industri, data tekstual yang sangat panjang ini dihapus karena tidak memberikan metrik kuantitatif yang relevan.
#
# **4. Star2, Star3, Star4**
#
# Ketiga kolom ini dihapus untuk menyederhanakan analisis pengaruh aktor terhadap kesuksesan film. Dengan memfokuskan data hanya pada aktor utama (Star1), kita dapat melakukan segmentasi Star Power yang lebih bersih dan menghindari tumpang tindih data aktor pendukung yang jumlahnya terlalu banyak untuk dipetakan secara efektif.

# %%
df = df.drop(['Poster_Link', 'Genre', 'Overview', 'Star2', 'Star3', 'Star4'], axis=1)

# %% [markdown]
# Perintah di atas merupakan instruksi untuk menghapus kolom sekaligus dalam sebuah DataFrame.

# %%
df
# Out:
#                  Series_Title  Released_Year  Runtime  IMDB_Rating  \
# 0    The Shawshank Redemption           1994      142          9.3
# 1               The Godfather           1972      175          9.2
# 2             The Dark Knight           2008      152          9.0
# 3      The Godfather: Part II           1974      188          9.0
# 4                12 Angry Men           1957       96          9.0
# ..                        ...            ...      ...          ...
# 995    Breakfast at Tiffany's           1961      115          7.6
# 996                     Giant           1956      188          7.6
# 997     From Here to Eternity           1953      118          7.6
# 998                  Lifeboat           1944       97          7.6
# 999              The 39 Steps           1935       86          7.6
#
#      Meta_score              Director              Star1  No_of_Votes  \
# 0          80.0        Frank Darabont        Tim Robbins      2343110
# ...

# %% [markdown]
# Setelah dilakukan data reduction terlihat di atas bahwa sekarang hanya ada 10 kolom tersisa. Ini menunjukan bahwa data reduction telah berhasil dilakukan. Dengan dataset yang awalnya memiliki banyak variabel kompleks disederhanakan menjadi variabel yang hanya memiliki nilai strategis. Manfaat utama dari langkah ini adalah meningkatkan fokus analisis, di mana kita membuang 'kebisingan' (noise) dari data tidak terstruktur seperti URL poster dan sinopsis film yang tidak bisa dihitung secara statistik. Selain itu, reduksi data berfungsi untuk menghindari redundansi, seperti menghapus kolom Genre asli yang sudah diwakili oleh Main_Genre.

# %% [markdown]
# ## **Menyimpan dataset (Bersih)**

# %%
df.to_csv('[Bersih]IMDbTop1000.csv', index=False)
